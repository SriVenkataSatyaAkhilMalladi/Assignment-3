# %% [markdown]
# # Edit Your Expectation Suite
# Use this notebook to recreate and modify your expectation suite:
#
# **Expectation Suite Name**: `nexrad_suite`

# %%
import datetime

import pandas as pd

import great_expectations as gx
import great_expectations.jupyter_ux
from great_expectations.core.batch import BatchRequest
from great_expectations.checkpoint import SimpleCheckpoint
from great_expectations.exceptions import DataContextError

context = gx.get_context()

# Note that if you modify this batch request, you may save the new version as a .json file
#  to pass in later via the --batch-request option
batch_request = {'datasource_name': 'goes18', 'data_connector_name': 'default_inferred_data_connector_name', 'data_asset_name': 'folders_202302091623', 'limit': 1000}


# Feel free to change the name of your suite here. Renaming this will not remove the other one.
expectation_suite_name = "nexrad_suite"
try:
    suite = context.get_expectation_suite(expectation_suite_name=expectation_suite_name)
    print(f'Loaded ExpectationSuite "{suite.expectation_suite_name}" containing {len(suite.expectations)} expectations.')
except DataContextError:
    suite = context.create_expectation_suite(expectation_suite_name=expectation_suite_name)
    print(f'Created ExpectationSuite "{suite.expectation_suite_name}".')


validator = context.get_validator(
    batch_request=BatchRequest(**batch_request),
    expectation_suite_name=expectation_suite_name
)
column_names = [f'"{column_name}"' for column_name in validator.columns()]
print(f"Columns: {', '.join(column_names)}.")
validator.head(n_rows=5, fetch_all=False)
# Out:
# 2023-02-09T16:56:44-0500 - INFO - FileDataContext loading zep config
# 2023-02-09T16:56:44-0500 - INFO - GxConfig.parse_yaml() failed with errors - [{'loc': ('xdatasources',), 'msg': 'field required', 'type': 'value_error.missing'}]
# 2023-02-09T16:56:44-0500 - INFO - GxConfig.parse_yaml() returning empty `xdatasources`
# 2023-02-09T16:56:44-0500 - INFO - Loading 'datasources' ->
# {}
# 2023-02-09T16:56:44-0500 - INFO - Loaded 'datasources' ->
# {}
# Loaded ExpectationSuite "nexrad_suite" containing 2 expectations.
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# Columns: "month", "day", "nexrad_station", "Is2022".
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#    month  day nexrad_station  Is2022
# 0      1    1           FOP1       0
# 1      1    1           KABR       0
# 2      1    1           KABX       0
# 3      1    1           KAKQ       0
# 4      1    1           KAMA       0

# %% [markdown]
# ## Create & Edit Expectations
#
#
# Add expectations by calling specific expectation methods on the `validator` object. They all begin with `.expect_` which makes autocompleting easy using tab.
#
# Because you selected interactive mode, you are now creating or editing an Expectation Suite with validator feedback from the sample batch of data that you specified (see `batch_request`).
#
# Note that if you select manual mode you may still create or edit an Expectation Suite directly, without feedback from the `validator`. See our documentation for more info and examples: [How to create a new Expectation Suite without a sample batch](https://docs.greatexpectations.io/docs/guides/expectations/how_to_create_and_edit_expectations_based_on_domain_knowledge_without_inspecting_data_directly).
#
#
#
# You can see all the available expectations in the **[expectation gallery](https://greatexpectations.io/expectations)**.

# %% [markdown]
# ### Table Expectation(s)

# %%
validator.expect_table_row_count_to_be_between(max_value=81050, min_value=81050)
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "result": {
#     "observed_value": 81050
#   },
#   "meta": {},
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
validator.expect_table_columns_to_match_set(column_set=['month', 'Is2022', 'day', 'nexrad_station'])
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# {
#   "result": {
#     "observed_value": [
#       "month",
#       "day",
#       "nexrad_station",
#       "Is2022"
#     ]
#   },
#   "meta": {},
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Column Expectation(s)

# %% [markdown]
# No column level expectations are in this suite. Feel free to add some here.
#
# They all begin with`validator.expect_column_...`.

# %%
#YEAR Column validations
validator.expect_column_distinct_values_to_be_in_set(column='Is2022', value_set=[0, 1])
validator.expect_column_values_to_not_be_null(column='Is2022')
# Out:
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# {
#   "result": {
#     "element_count": 81050,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
#Month Column validations
validator.expect_column_values_to_not_be_null(column='month')
validator.expect_column_values_to_be_between(column='month', max_value=12, min_value=1)
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "result": {
#     "element_count": 81050,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
#Day Column validations
validator.expect_column_values_to_not_be_null(column='day')
validator.expect_column_values_to_be_between(column='day', max_value=31, min_value=1)
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "result": {
#     "element_count": 81050,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
#NEXRAD STATION Column validations
df = pd.read_csv("../../results/nexrad_stations.csv")
nexrad_stations = [x for x in df['nexrad_station']]
validator.expect_column_values_to_not_be_null(column='nexrad_station')
validator.expect_column_distinct_values_to_be_in_set(column='nexrad_station', value_set = nexrad_stations)
# Out:
# Calculating Metrics:   0%|          | 0/6 [00:00<?, ?it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# {
#   "result": {
#     "observed_value": [
#       "DOP1",
#       "FOP1",
#       "KABR",
#       "KABX",
#       "KAKQ",
#       "KAMA",
#       "KAMX",
#       "KAPX",
#       "KARX",
#       "KATX",
#       "KBBX",
#       "KBGM",
#       "KBHX",
#       "KBIS",
#       "KBLX",
#       "KBMX",
#       "KBOX",
#       "KBRO",
#       "KBUF",
#       "KBYX",
#       "KCAE",
#       "KCBW",
#       "KCBX",
#       "KCCX",
#       "KCLE",
#       "KCLX",
#       "KCRP",
#       "KCXX",
#       "KCYS",
#       "KDAX",
#       "KDDC",
#       "KDFX",
#       "KDGX",
#       "KDIX",
#       "KDLH",
#       "KDMX",
#       "KDOX",
#       "KDTX",
#       "KDVN",
#       "KDYX",
#       "KEAX",
#       "KEMX",
#       "KENX",
#       "KEOX",
#       "KEPZ",
#       "KESX",
#       "KEVX",
#       "KEWX",
#       "KEYX",
#       "KFCX",
#       "KFDR",
#       "KFDX",
#       "KFFC",
#       "KFSD",
#       "KFSX",
#       "KFTG",
#       "KFWS",
#       "KGGW",
#       "KGJX",
#       "KGLD",
#       "KGRB",
#       "KGRK",
#       "KGRR",
#       "KGSP",
#       "KGWX",
#       "KGYX",
#       "KHDX",
#       "KHGX",
#       "KHNX",
#       "KHPX",
#       "KHTX",
#       "KICT",
#       "KICX",
#       "KILN",
#       "KILX",
#       "KIND",
#       "KINX",
#       "KIWA",
#       "KIWX",
#       "KJAX",
#       "KJGX",
#       "KJKL",
#       "KLBB",
#       "KLCH",
#       "KLGX",
#       "KLIX",
#       "KLNX",
#       "KLOT",
#       "KLRX",
#       "KLSX",
#       "KLTX",
#       "KLVX",
#       "KLWX",
#       "KLZK",
#       "KMAF",
#       "KMAX",
#       "KMBX",
#       "KMHX",
#       "KMKX",
#       "KMLB",
#       "KMOB",
#       "KMPX",
#       "KMQT",
#       "KMRX",
#       "KMSX",
#       "KMTX",
#       "KMUX",
#       "KMVX",
#       "KMXX",
#       "KNKX",
#       "KNQA",
#       "KOAX",
#       "KOHX",
#       "KOKX",
#       "KOTX",
#       "KPAH",
#       "KPBZ",
#       "KPDT",
#       "KPOE",
#       "KPUX",
#       "KRAX",
#       "KRGX",
#       "KRIW",
#       "KRLX",
#       "KRTX",
#       "KSFX",
#       "KSGF",
#       "KSHV",
#       "KSJT",
#       "KSOX",
#       "KSRX",
#       "KTBW",
#       "KTFX",
#       "KTLH",
#       "KTLX",
#       "KTWX",
#       "KTYX",
#       "KUDX",
#       "KUEX",
#       "KVAX",
#       "KVBX",
#       "KVNX",
#       "KVTX",
#       "KVWX",
#       "KYUX",
#       "NOP4",
#       "PABC",
#       "PACG",
#       "PAEC",
#       "PAHG",
#       "PAIH",
#       "PAKC",
#       "PAPD",
#       "PGUA",
#       "PHKI",
#       "PHKM",
#       "PHMO",
#       "PHWA",
#       "RKJK",
#       "RKSG",
#       "RODN",
#       "ROP4",
#       "TADW",
#       "TATL",
#       "TBNA",
#       "TBOS",
#       "TBWI",
#       "TCLT",
#       "TCMH",
#       "TCVG",
#       "TDAL",
#       "TDAY",
#       "TDCA",
#       "TDEN",
#       "TDFW",
#       "TDTW",
#       "TEWR",
#       "TFLL",
#       "THOU",
#       "TIAD",
#       "TIAH",
#       "TICH",
#       "TIDS",
#       "TJFK",
#       "TJUA",
#       "TLAS",
#       "TLVE",
#       "TMCI",
#       "TMCO",
#       "TMDW",
#       "TMEM",
#       "TMIA",
#       "TMKE",
#       "TMSP",
#       "TMSY",
#       "TOKC",
#       "TORD",
#       "TPBI",
#       "TPHL",
#       "TPHX",
#       "TPIT",
#       "TRDU",
#       "TSDF",
#       "TSJU",
#       "TSLC",
#       "TSTL",
#       "TTPA",
#       "TTUL"
#     ],
#     "details": {
#       "value_counts": [
#         {
#           "value": "DOP1",
#           "count": 2
#         },
#         {
#           "value": "FOP1",
#           "count": 387
#         },
#         {
#           "value": "KABR",
#           "count": 405
#         },
#         {
#           "value": "KABX",
#           "count": 405
#         },
#         {
#           "value": "KAKQ",
#           "count": 394
#         },
#         {
#           "value": "KAMA",
#           "count": 405
#         },
#         {
#           "value": "KAMX",
#           "count": 405
#         },
#         {
#           "value": "KAPX",
#           "count": 321
#         },
#         {
#           "value": "KARX",
#           "count": 405
#         },
#         {
#           "value": "KATX",
#           "count": 400
#         },
#         {
#           "value": "KBBX",
#           "count": 405
#         },
#         {
#           "value": "KBGM",
#           "count": 405
#         },
#         {
#           "value": "KBHX",
#           "count": 405
#         },
#         {
#           "value": "KBIS",
#           "count": 405
#         },
#         {
#           "value": "KBLX",
#           "count": 405
#         },
#         {
#           "value": "KBMX",
#           "count": 405
#         },
#         {
#           "value": "KBOX",
#           "count": 405
#         },
#         {
#           "value": "KBRO",
#           "count": 405
#         },
#         {
#           "value": "KBUF",
#           "count": 405
#         },
#         {
#           "value": "KBYX",
#           "count": 405
#         },
#         {
#           "value": "KCAE",
#           "count": 405
#         },
#         {
#           "value": "KCBW",
#           "count": 405
#         },
#         {
#           "value": "KCBX",
#           "count": 405
#         },
#         {
#           "value": "KCCX",
#           "count": 405
#         },
#         {
#           "value": "KCLE",
#           "count": 405
#         },
#         {
#           "value": "KCLX",
#           "count": 405
#         },
#         {
#           "value": "KCRP",
#           "count": 405
#         },
#         {
#           "value": "KCXX",
#           "count": 405
#         },
#         {
#           "value": "KCYS",
#           "count": 405
#         },
#         {
#           "value": "KDAX",
#           "count": 405
#         },
#         {
#           "value": "KDDC",
#           "count": 405
#         },
#         {
#           "value": "KDFX",
#           "count": 340
#         },
#         {
#           "value": "KDGX",
#           "count": 405
#         },
#         {
#           "value": "KDIX",
#           "count": 405
#         },
#         {
#           "value": "KDLH",
#           "count": 405
#         },
#         {
#           "value": "KDMX",
#           "count": 405
#         },
#         {
#           "value": "KDOX",
#           "count": 405
#         },
#         {
#           "value": "KDTX",
#           "count": 328
#         },
#         {
#           "value": "KDVN",
#           "count": 405
#         },
#         {
#           "value": "KDYX",
#           "count": 405
#         },
#         {
#           "value": "KEAX",
#           "count": 405
#         },
#         {
#           "value": "KEMX",
#           "count": 405
#         },
#         {
#           "value": "KENX",
#           "count": 405
#         },
#         {
#           "value": "KEOX",
#           "count": 405
#         },
#         {
#           "value": "KEPZ",
#           "count": 405
#         },
#         {
#           "value": "KESX",
#           "count": 405
#         },
#         {
#           "value": "KEVX",
#           "count": 405
#         },
#         {
#           "value": "KEWX",
#           "count": 405
#         },
#         {
#           "value": "KEYX",
#           "count": 405
#         },
#         {
#           "value": "KFCX",
#           "count": 405
#         },
#         {
#           "value": "KFDR",
#           "count": 405
#         },
#         {
#           "value": "KFDX",
#           "count": 381
#         },
#         {
#           "value": "KFFC",
#           "count": 405
#         },
#         {
#           "value": "KFSD",
#           "count": 405
#         },
#         {
#           "value": "KFSX",
#           "count": 405
#         },
#         {
#           "value": "KFTG",
#           "count": 405
#         },
#         {
#           "value": "KFWS",
#           "count": 405
#         },
#         {
#           "value": "KGGW",
#           "count": 405
#         },
#         {
#           "value": "KGJX",
#           "count": 405
#         },
#         {
#           "value": "KGLD",
#           "count": 404
#         },
#         {
#           "value": "KGRB",
#           "count": 403
#         },
#         {
#           "value": "KGRK",
#           "count": 405
#         },
#         {
#           "value": "KGRR",
#           "count": 405
#         },
#         {
#           "value": "KGSP",
#           "count": 365
#         },
#         {
#           "value": "KGWX",
#           "count": 405
#         },
#         {
#           "value": "KGYX",
#           "count": 405
#         },
#         {
#           "value": "KHDX",
#           "count": 333
#         },
#         {
#           "value": "KHGX",
#           "count": 405
#         },
#         {
#           "value": "KHNX",
#           "count": 405
#         },
#         {
#           "value": "KHPX",
#           "count": 383
#         },
#         {
#           "value": "KHTX",
#           "count": 405
#         },
#         {
#           "value": "KICT",
#           "count": 405
#         },
#         {
#           "value": "KICX",
#           "count": 405
#         },
#         {
#           "value": "KILN",
#           "count": 405
#         },
#         {
#           "value": "KILX",
#           "count": 405
#         },
#         {
#           "value": "KIND",
#           "count": 405
#         },
#         {
#           "value": "KINX",
#           "count": 405
#         },
#         {
#           "value": "KIWA",
#           "count": 405
#         },
#         {
#           "value": "KIWX",
#           "count": 405
#         },
#         {
#           "value": "KJAX",
#           "count": 405
#         },
#         {
#           "value": "KJGX",
#           "count": 321
#         },
#         {
#           "value": "KJKL",
#           "count": 405
#         },
#         {
#           "value": "KLBB",
#           "count": 405
#         },
#         {
#           "value": "KLCH",
#           "count": 405
#         },
#         {
#           "value": "KLGX",
#           "count": 401
#         },
#         {
#           "value": "KLIX",
#           "count": 394
#         },
#         {
#           "value": "KLNX",
#           "count": 405
#         },
#         {
#           "value": "KLOT",
#           "count": 405
#         },
#         {
#           "value": "KLRX",
#           "count": 405
#         },
#         {
#           "value": "KLSX",
#           "count": 405
#         },
#         {
#           "value": "KLTX",
#           "count": 392
#         },
#         {
#           "value": "KLVX",
#           "count": 405
#         },
#         {
#           "value": "KLWX",
#           "count": 405
#         },
#         {
#           "value": "KLZK",
#           "count": 402
#         },
#         {
#           "value": "KMAF",
#           "count": 405
#         },
#         {
#           "value": "KMAX",
#           "count": 405
#         },
#         {
#           "value": "KMBX",
#           "count": 405
#         },
#         {
#           "value": "KMHX",
#           "count": 405
#         },
#         {
#           "value": "KMKX",
#           "count": 405
#         },
#         {
#           "value": "KMLB",
#           "count": 405
#         },
#         {
#           "value": "KMOB",
#           "count": 399
#         },
#         {
#           "value": "KMPX",
#           "count": 405
#         },
#         {
#           "value": "KMQT",
#           "count": 405
#         },
#         {
#           "value": "KMRX",
#           "count": 405
#         },
#         {
#           "value": "KMSX",
#           "count": 405
#         },
#         {
#           "value": "KMTX",
#           "count": 405
#         },
#         {
#           "value": "KMUX",
#           "count": 405
#         },
#         {
#           "value": "KMVX",
#           "count": 405
#         },
#         {
#           "value": "KMXX",
#           "count": 405
#         },
#         {
#           "value": "KNKX",
#           "count": 404
#         },
#         {
#           "value": "KNQA",
#           "count": 405
#         },
#         {
#           "value": "KOAX",
#           "count": 405
#         },
#         {
#           "value": "KOHX",
#           "count": 405
#         },
#         {
#           "value": "KOKX",
#           "count": 393
#         },
#         {
#           "value": "KOTX",
#           "count": 400
#         },
#         {
#           "value": "KPAH",
#           "count": 405
#         },
#         {
#           "value": "KPBZ",
#           "count": 405
#         },
#         {
#           "value": "KPDT",
#           "count": 405
#         },
#         {
#           "value": "KPOE",
#           "count": 405
#         },
#         {
#           "value": "KPUX",
#           "count": 405
#         },
#         {
#           "value": "KRAX",
#           "count": 405
#         },
#         {
#           "value": "KRGX",
#           "count": 405
#         },
#         {
#           "value": "KRIW",
#           "count": 405
#         },
#         {
#           "value": "KRLX",
#           "count": 405
#         },
#         {
#           "value": "KRTX",
#           "count": 405
#         },
#         {
#           "value": "KSFX",
#           "count": 405
#         },
#         {
#           "value": "KSGF",
#           "count": 393
#         },
#         {
#           "value": "KSHV",
#           "count": 401
#         },
#         {
#           "value": "KSJT",
#           "count": 405
#         },
#         {
#           "value": "KSOX",
#           "count": 405
#         },
#         {
#           "value": "KSRX",
#           "count": 405
#         },
#         {
#           "value": "KTBW",
#           "count": 405
#         },
#         {
#           "value": "KTFX",
#           "count": 405
#         },
#         {
#           "value": "KTLH",
#           "count": 328
#         },
#         {
#           "value": "KTLX",
#           "count": 405
#         },
#         {
#           "value": "KTWX",
#           "count": 405
#         },
#         {
#           "value": "KTYX",
#           "count": 405
#         },
#         {
#           "value": "KUDX",
#           "count": 405
#         },
#         {
#           "value": "KUEX",
#           "count": 405
#         },
#         {
#           "value": "KVAX",
#           "count": 405
#         },
#         {
#           "value": "KVBX",
#           "count": 405
#         },
#         {
#           "value": "KVNX",
#           "count": 405
#         },
#         {
#           "value": "KVTX",
#           "count": 405
#         },
#         {
#           "value": "KVWX",
#           "count": 405
#         },
#         {
#           "value": "KYUX",
#           "count": 405
#         },
#         {
#           "value": "NOP4",
#           "count": 11
#         },
#         {
#           "value": "PABC",
#           "count": 385
#         },
#         {
#           "value": "PACG",
#           "count": 405
#         },
#         {
#           "value": "PAEC",
#           "count": 405
#         },
#         {
#           "value": "PAHG",
#           "count": 393
#         },
#         {
#           "value": "PAIH",
#           "count": 395
#         },
#         {
#           "value": "PAKC",
#           "count": 404
#         },
#         {
#           "value": "PAPD",
#           "count": 405
#         },
#         {
#           "value": "PGUA",
#           "count": 231
#         },
#         {
#           "value": "PHKI",
#           "count": 404
#         },
#         {
#           "value": "PHKM",
#           "count": 404
#         },
#         {
#           "value": "PHMO",
#           "count": 405
#         },
#         {
#           "value": "PHWA",
#           "count": 405
#         },
#         {
#           "value": "RKJK",
#           "count": 405
#         },
#         {
#           "value": "RKSG",
#           "count": 370
#         },
#         {
#           "value": "RODN",
#           "count": 398
#         },
#         {
#           "value": "ROP4",
#           "count": 8
#         },
#         {
#           "value": "TADW",
#           "count": 403
#         },
#         {
#           "value": "TATL",
#           "count": 369
#         },
#         {
#           "value": "TBNA",
#           "count": 405
#         },
#         {
#           "value": "TBOS",
#           "count": 405
#         },
#         {
#           "value": "TBWI",
#           "count": 405
#         },
#         {
#           "value": "TCLT",
#           "count": 405
#         },
#         {
#           "value": "TCMH",
#           "count": 403
#         },
#         {
#           "value": "TCVG",
#           "count": 405
#         },
#         {
#           "value": "TDAL",
#           "count": 405
#         },
#         {
#           "value": "TDAY",
#           "count": 405
#         },
#         {
#           "value": "TDCA",
#           "count": 405
#         },
#         {
#           "value": "TDEN",
#           "count": 405
#         },
#         {
#           "value": "TDFW",
#           "count": 401
#         },
#         {
#           "value": "TDTW",
#           "count": 321
#         },
#         {
#           "value": "TEWR",
#           "count": 112
#         },
#         {
#           "value": "TFLL",
#           "count": 405
#         },
#         {
#           "value": "THOU",
#           "count": 345
#         },
#         {
#           "value": "TIAD",
#           "count": 405
#         },
#         {
#           "value": "TIAH",
#           "count": 405
#         },
#         {
#           "value": "TICH",
#           "count": 390
#         },
#         {
#           "value": "TIDS",
#           "count": 405
#         },
#         {
#           "value": "TJFK",
#           "count": 405
#         },
#         {
#           "value": "TJUA",
#           "count": 405
#         },
#         {
#           "value": "TLAS",
#           "count": 405
#         },
#         {
#           "value": "TLVE",
#           "count": 405
#         },
#         {
#           "value": "TMCI",
#           "count": 405
#         },
#         {
#           "value": "TMCO",
#           "count": 405
#         },
#         {
#           "value": "TMDW",
#           "count": 345
#         },
#         {
#           "value": "TMEM",
#           "count": 405
#         },
#         {
#           "value": "TMIA",
#           "count": 405
#         },
#         {
#           "value": "TMKE",
#           "count": 394
#         },
#         {
#           "value": "TMSP",
#           "count": 405
#         },
#         {
#           "value": "TMSY",
#           "count": 401
#         },
#         {
#           "value": "TOKC",
#           "count": 297
#         },
#         {
#           "value": "TORD",
#           "count": 405
#         },
#         {
#           "value": "TPBI",
#           "count": 401
#         },
#         {
#           "value": "TPHL",
#           "count": 405
#         },
#         {
#           "value": "TPHX",
#           "count": 381
#         },
#         {
#           "value": "TPIT",
#           "count": 403
#         },
#         {
#           "value": "TRDU",
#           "count": 404
#         },
#         {
#           "value": "TSDF",
#           "count": 399
#         },
#         {
#           "value": "TSJU",
#           "count": 40
#         },
#         {
#           "value": "TSLC",
#           "count": 405
#         },
#         {
#           "value": "TSTL",
#           "count": 405
#         },
#         {
#           "value": "TTPA",
#           "count": 404
#         },
#         {
#           "value": "TTUL",
#           "count": 405
#         }
#       ]
#     }
#   },
#   "meta": {},
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ## Review & Save Your Expectations
#
# Let's save the expectation suite as a JSON file in the `great_expectations/expectations` directory of your project.
#
# Let's now rebuild your Data Docs, which helps you communicate about your data with both machines and humans.

# %%
print(validator.get_expectation_suite(discard_failed_expectations=False))
validator.save_expectation_suite(discard_failed_expectations=False)

checkpoint_config = {
    "class_name": "SimpleCheckpoint",
    "validations": [
        {
            "batch_request": batch_request,
            "expectation_suite_name": expectation_suite_name
        }
    ]
}
checkpoint = SimpleCheckpoint(
    f"{validator.active_batch_definition.data_asset_name}_{expectation_suite_name}",
    context,
    **checkpoint_config
)
checkpoint_result = checkpoint.run()

context.build_data_docs()

validation_result_identifier = checkpoint_result.list_validation_result_identifiers()[0]
context.open_data_docs(resource_identifier=validation_result_identifier)
# Out:
# 2023-02-09T16:56:45-0500 - INFO - 	10 expectation(s) included in expectation_suite.
# {
#   "ge_cloud_id": null,
#   "meta": {
#     "citations": [
#       {
#         "citation_date": "2023-02-09T21:28:59.367473Z",
#         "comment": "Created by effective Rule-Based Profiler of OnboardingDataAssistant with the configuration included.\n"
#       },
#       {
#         "batch_request": {
#           "data_asset_name": "folders_202302091623",
#           "data_connector_name": "default_inferred_data_connector_name",
#           "datasource_name": "goes18",
#           "limit": 1000
#         },
#         "citation_date": "2023-02-09T21:33:15.345436Z",
#         "comment": "Created suite added via CLI"
#       }
#     ],
#     "great_expectations_version": "0.15.47"
#   },
#   "expectation_suite_name": "nexrad_suite",
#   "expectations": [
#     {
#       "meta": {},
#       "kwargs": {
#         "max_value": 81050,
#         "min_value": 81050
#       },
#       "expectation_type": "expect_table_row_count_to_be_between"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column_set": [
#           "month",
#           "Is2022",
#           "day",
#           "nexrad_station"
#         ]
#       },
#       "expectation_type": "expect_table_columns_to_match_set"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "Is2022",
#         "value_set": [
#           0,
#           1
#         ]
#       },
#       "expectation_type": "expect_column_distinct_values_to_be_in_set"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "Is2022"
#       },
#       "expectation_type": "expect_column_values_to_not_be_null"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "month"
#       },
#       "expectation_type": "expect_column_values_to_not_be_null"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "month",
#         "max_value": 12,
#         "min_value": 1
#       },
#       "expectation_type": "expect_column_values_to_be_between"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "day"
#       },
#       "expectation_type": "expect_column_values_to_not_be_null"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "day",
#         "max_value": 31,
#         "min_value": 1
#       },
#       "expectation_type": "expect_column_values_to_be_between"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "nexrad_station"
#       },
#       "expectation_type": "expect_column_values_to_not_be_null"
#     },
#     {
#       "meta": {},
#       "kwargs": {
#         "column": "nexrad_station",
#         "value_set": [
#           "FOP1",
#           "KABR",
#           "KABX",
#           "KAKQ",
#           "KAMA",
#           "KAMX",
#           "KAPX",
#           "KARX",
#           "KATX",
#           "KBBX",
#           "KBGM",
#           "KBHX",
#           "KBIS",
#           "KBLX",
#           "KBMX",
#           "KBOX",
#           "KBRO",
#           "KBUF",
#           "KBYX",
#           "KCAE",
#           "KCBW",
#           "KCBX",
#           "KCCX",
#           "KCLE",
#           "KCLX",
#           "KCRP",
#           "KCXX",
#           "KCYS",
#           "KDAX",
#           "KDDC",
#           "KDFX",
#           "KDGX",
#           "KDIX",
#           "KDLH",
#           "KDMX",
#           "KDOX",
#           "KDTX",
#           "KDVN",
#           "KDYX",
#           "KEAX",
#           "KEMX",
#           "KENX",
#           "KEOX",
#           "KEPZ",
#           "KESX",
#           "KEVX",
#           "KEWX",
#           "KEYX",
#           "KFCX",
#           "KFDR",
#           "KFDX",
#           "KFFC",
#           "KFSD",
#           "KFSX",
#           "KFTG",
#           "KFWS",
#           "KGGW",
#           "KGJX",
#           "KGLD",
#           "KGRB",
#           "KGRK",
#           "KGRR",
#           "KGSP",
#           "KGWX",
#           "KGYX",
#           "KHDX",
#           "KHGX",
#           "KHNX",
#           "KHPX",
#           "KHTX",
#           "KICT",
#           "KICX",
#           "KILN",
#           "KILX",
#           "KIND",
#           "KINX",
#           "KIWA",
#           "KIWX",
#           "KJAX",
#           "KJGX",
#           "KJKL",
#           "KLBB",
#           "KLCH",
#           "KLGX",
#           "KLIX",
#           "KLNX",
#           "KLOT",
#           "KLRX",
#           "KLSX",
#           "KLTX",
#           "KLVX",
#           "KLWX",
#           "KLZK",
#           "KMAF",
#           "KMAX",
#           "KMBX",
#           "KMHX",
#           "KMKX",
#           "KMLB",
#           "KMOB",
#           "KMPX",
#           "KMQT",
#           "KMRX",
#           "KMSX",
#           "KMTX",
#           "KMUX",
#           "KMVX",
#           "KMXX",
#           "KNKX",
#           "KNQA",
#           "KOAX",
#           "KOHX",
#           "KOKX",
#           "KOTX",
#           "KPAH",
#           "KPBZ",
#           "KPDT",
#           "KPOE",
#           "KPUX",
#           "KRAX",
#           "KRGX",
#           "KRIW",
#           "KRLX",
#           "KRTX",
#           "KSFX",
#           "KSGF",
#           "KSHV",
#           "KSJT",
#           "KSOX",
#           "KSRX",
#           "KTBW",
#           "KTFX",
#           "KTLH",
#           "KTLX",
#           "KTWX",
#           "KTYX",
#           "KUDX",
#           "KUEX",
#           "KVAX",
#           "KVBX",
#           "KVNX",
#           "KVTX",
#           "KVWX",
#           "KYUX",
#           "PABC",
#           "PACG",
#           "PAEC",
#           "PAHG",
#           "PAIH",
#           "PAKC",
#           "PAPD",
#           "PHKI",
#           "PHKM",
#           "PHMO",
#           "PHWA",
#           "RKJK",
#           "RKSG",
#           "RODN",
#           "TADW",
#           "TBNA",
#           "TBOS",
#           "TBWI",
#           "TCLT",
#           "TCMH",
#           "TCVG",
#           "TDAL",
#           "TDAY",
#           "TDCA",
#           "TDEN",
#           "TDFW",
#           "TDTW",
#           "TEWR",
#           "TFLL",
#           "THOU",
#           "TIAD",
#           "TIAH",
#           "TICH",
#           "TIDS",
#           "TJFK",
#           "TJUA",
#           "TLAS",
#           "TLVE",
#           "TMCI",
#           "TMCO",
#           "TMDW",
#           "TMEM",
#           "TMIA",
#           "TMKE",
#           "TMSP",
#           "TMSY",
#           "TOKC",
#           "TORD",
#           "TPBI",
#           "TPHL",
#           "TPHX",
#           "TPIT",
#           "TRDU",
#           "TSDF",
#           "TSLC",
#           "TSTL",
#           "TTPA",
#           "TTUL",
#           "TATL",
#           "PGUA",
#           "TSJU",
#           "NOP4",
#           "ROP4",
#           "DOP1"
#         ]
#       },
#       "expectation_type": "expect_column_distinct_values_to_be_in_set"
#     }
#   ],
#   "data_asset_type": null
# }
# 2023-02-09T16:56:45-0500 - INFO - 	10 expectation(s) included in expectation_suite.
# 2023-02-09T16:56:46-0500 - INFO - 	10 expectation(s) included in expectation_suite.
# Calculating Metrics:   0%|          | 0/35 [00:00<?, ?it/s]
